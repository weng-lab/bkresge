# %%
import polars as pl

# %%
ds = pl.scan_parquet(
    "/zata/zippy/kresgeb/nmf_stuff/dlPFC/data/batched_nmf/all_patterns_partitioned"
)

df = ds.filter((pl.col("loading") > 0) & (pl.col("k") == 10)).pivot(on = "gene")
# Out:
#   Cell In[6], line 6
#     .pivot(on = "gene")
#     ^
# SyntaxError: invalid syntax
